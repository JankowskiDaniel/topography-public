# %%
from topography.data.generate_noise import generate_average_noise_dataset
from topography.data.generate_dataset import ge

# %%
generate_average_noise_dataset(
    path="../data/average_noise/steel/",
    path_to_raw="../data/raw/steel/1channel/",
    num_images=1000,
)
# Out:
# 100%|██████████| 1000/1000 [09:42<00:00,  1.72it/s]

# %%
import sys

sys.path.append("..\src")
sys.path.append("src")

# %%
from data_generation.datasets.generator import generate_dataset

# %%
path = r"C:\Users\janko\OneDrive\Pulpit\Artificial intelligence\Magisterka\topography-public\data\generated\all\steel\\"
path_average_noise = r"C:\Users\janko\OneDrive\Pulpit\Artificial intelligence\Magisterka\topography-public\data\noise\steel\\"
generate_dataset(
    noise_type=["average", "bubble", "pizza", "blackbox"],
    path=path,
    n_copies=10,
    name_prefix="all_2",
    epsilon_range=(0.250, 0.500),
    parameters_filename="parameters2.csv",
    **{"path_average_noise": path_average_noise},
)
# Out:
# ...
# 100%|██████████| 250/250 [27:47<00:00,  6.67s/it]
